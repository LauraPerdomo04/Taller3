# %%
import pandas as pd

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report,confusion_matrix

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading the dataset

# %%
# Reading CSV
cancer_df = pd.read_csv('./data/cancer.csv', sep = ',')

# %%
# Deleting unused column
del cancer_df['Unnamed: 32']

# %%
cancer_df.shape
# Out:
# (569, 32)

# %%
cancer_df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Splitting train and test datasets

# %%
# Selecting features to train the model
features = cancer_df.columns.tolist()[2:]

# %%
# Creating feature matrix
X = cancer_df[features]

# %%
# Creating target
Y = cancer_df['diagnosis'].replace({'B': 0, 'M': 1})

# %%
pd.Series(Y).value_counts(normalize = True)
# Out:
# 0    0.627417
# 1    0.372583
# Name: diagnosis, dtype: float64

# %%
# Splitting feature matrix for training (70%) and test (30%)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, stratify = Y)

# %%
pd.Series(Y_train).value_counts(normalize = True)
# Out:
# 0    0.628141
# 1    0.371859
# Name: diagnosis, dtype: float64

# %%
pd.Series(Y_test).value_counts(normalize = True)
# Out:
# 0    0.625731
# 1    0.374269
# Name: diagnosis, dtype: float64

# %% [markdown]
# ### Training the model

# %%
# Initializing the model
model = DecisionTreeClassifier()

# %%
# Training the model using training dataset
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Plotting the tree model
plt.figure(figsize = (30, 20))
plot_tree(model, feature_names = features, class_names = ['B', 'M'])
# Out:
# [Text(982.5652173913044, 1009.5428571428572, 'concave points_mean <= 0.056\ngini = 0.467\nsamples = 398\nvalue = [250, 148]\nclass = B'),
#  Text(655.0434782608695, 854.2285714285715, 'radius_worst <= 16.795\ngini = 0.143\nsamples = 259\nvalue = [239, 20]\nclass = B'),
#  Text(436.695652173913, 698.9142857142858, 'area_se <= 33.005\ngini = 0.065\nsamples = 238\nvalue = [230, 8]\nclass = B'),
#  Text(218.3478260869565, 543.6, 'concave points_worst <= 0.193\ngini = 0.018\nsamples = 217\nvalue = [215, 2]\nclass = B'),
#  Text(145.56521739130434, 388.28571428571433, 'texture_worst <= 33.27\ngini = 0.009\nsamples = 216\nvalue = [215, 1]\nclass = B'),
#  Text(72.78260869565217, 232.97142857142865, 'gini = 0.0\nsamples = 203\nvalue = [203, 0]\nclass = B'),
#  Text(218.3478260869565, 232.97142857142865, 'texture_worst <= 33.56\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = B'),
#  Text(145.56521739130434, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(291.1304347826087, 77.65714285714284, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = B'),
#  Text(291.1304347826087, 388.28571428571433, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(655.0434782608695, 543.6, 'concave points_worst <= 0.116\ngini = 0.408\nsamples = 21\nvalue = [15, 6]\nclass = B'),
#  Text(582.2608695652174, 388.28571428571433, 'symmetry_worst <= 0.2\ngini = 0.208\nsamples = 17\nvalue = [15, 2]\nclass = B'),
#  Text(509.4782608695652, 232.97142857142865, 'concave points_se <= 0.014\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = M'),
#  Text(436.695652173913, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = B'),
#  Text(582.2608695652174, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = M'),
#  Text(655.0434782608695, 232.97142857142865, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = B'),
#  Text(727.8260869565217, 388.28571428571433, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = M'),
#  Text(873.391304347826, 698.9142857142858, 'texture_mean <= 16.375\ngini = 0.49\nsamples = 21\nvalue = [9, 12]\nclass = M'),
#  Text(800.6086956521739, 543.6, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = B'),
#  Text(946.1739130434783, 543.6, 'symmetry_worst <= 0.259\ngini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = M'),
#  Text(873.391304347826, 388.28571428571433, 'area_se <= 47.58\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = B'),
#  Text(800.6086956521739, 232.97142857142865, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = B'),
#  Text(946.1739130434783, 232.97142857142865, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(1018.9565217391304, 388.28571428571433, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = M'),
#  Text(1310.086956521739, 854.2285714285715, 'concavity_worst <= 0.224\ngini = 0.146\nsamples = 139\nvalue = [11, 128]\nclass = M'),
#  Text(1164.5217391304348, 698.9142857142858, 'symmetry_mean <= 0.16\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = B'),
#  Text(1091.7391304347825, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = M'),
#  Text(1237.304347826087, 543.6, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = B'),
#  Text(1455.6521739130435, 698.9142857142858, 'area_se <= 13.93\ngini = 0.073\nsamples = 132\nvalue = [5, 127]\nclass = M'),
#  Text(1382.8695652173913, 543.6, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = B'),
#  Text(1528.4347826086955, 543.6, 'fractal_dimension_se <= 0.013\ngini = 0.031\nsamples = 129\nvalue = [2, 127]\nclass = M'),
#  Text(1455.6521739130435, 388.28571428571433, 'concave points_mean <= 0.056\ngini = 0.016\nsamples = 128\nvalue = [1, 127]\nclass = M'),
#  Text(1382.8695652173913, 232.97142857142865, 'texture_worst <= 25.89\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = M'),
#  Text(1310.086956521739, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = B'),
#  Text(1455.6521739130435, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = M'),
#  Text(1528.4347826086955, 232.97142857142865, 'gini = 0.0\nsamples = 125\nvalue = [0, 125]\nclass = M'),
#  Text(1601.2173913043478, 388.28571428571433, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = B')]

# %% [markdown]
# ### Evaluating the model

# %%
# Predicting for test dataset
predictions = model.predict(X_test)

# %%
# Plotting confusion matrix
confusion_matrix(Y_test, predictions)
# Out:
# array([[103,   4],
#        [  6,  58]], dtype=int64)

# %%
# Calculating confusion matrix derived metrics
print('Precision:', precision_score(Y_test, predictions))
print('Recall:', recall_score(Y_test, predictions))
print('F1:', f1_score(Y_test, predictions))
# Out:
# Precision: 0.8857142857142857
# Recall: 0.96875
# F1: 0.9253731343283582
